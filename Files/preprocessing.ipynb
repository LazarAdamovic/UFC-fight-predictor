# %%
#import libraries

import pandas as pd
import numpy as np
import regex as re
from datetime import datetime, timedelta
from cmath import nan
import matplotlib.pyplot as plt
import seaborn as sns
import copy

# %%
# notebook settings 

pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', None)
settings :  { "notebook.output.textLineLimit": 9999 }

# %%
# load data 

df = pd.read_csv('ufc-master.csv')

# %%
#describe

df.describe()
# Out:
#             R_odds       B_odds         R_ev         B_ev  no_of_rounds  \
# count  4895.000000  4896.000000  4895.000000  4896.000000   4896.000000
# mean   -117.640449    66.030637    94.827397   167.083323      3.181985
# std     268.881452   247.803928    82.843409   136.944643      0.571515
# min   -1700.000000 -1200.000000     5.882353     8.333333      3.000000
# 25%    -255.000000  -145.000000    39.215686    68.965517      3.000000
# 50%    -150.000000   130.000000    66.666667   130.000000      3.000000
# 75%     126.500000   220.000000   126.500000   220.000000      3.000000
# max     775.000000  1300.000000   775.000000  1300.000000      5.000000
#
#        B_current_lose_streak  B_current_win_streak       B_draw  \
# count            4896.000000           4896.000000  4896.000000
# mean                0.477941              0.875408     0.010621
# std                 0.769386              1.311379     0.108333
# min                 0.000000              0.000000     0.000000
# 25%                 0.000000              0.000000     0.000000
# 50%                 0.000000              0.000000     0.000000
# 75%                 1.000000              1.000000     0.000000
# max                 6.000000             12.000000     2.000000
#
#        B_avg_SIG_STR_landed  B_avg_SIG_STR_pct  B_avg_SUB_ATT  \
# count           3966.000000        4131.000000    4064.000000
# mean              26.308553           0.444741       0.504614
# std               20.935885           0.121332       0.680111
# min                0.000000           0.000000       0.000000
# 25%                5.610000           0.387500       0.000000
# 50%               24.759615           0.450000       0.297059
# 75%               39.075000           0.510000       0.800000
# max              154.000000           1.000000       7.000000
#
#        B_avg_TD_landed  B_avg_TD_pct  B_longest_win_streak     B_losses  \
# count      4063.000000   4054.000000            4896.00000  4896.000000
# mean          1.251173      0.312506               1.76491     1.726511
# std           1.337641      0.249412               1.88258     2.080347
# min           0.000000      0.000000               0.00000     0.000000
# 25%           0.250000      0.106063               0.00000     0.000000
# 50%           1.000000      0.310000               1.00000     1.000000
# 75%           1.846154      0.466979               3.00000     3.000000
# max          10.860000      1.000000              17.00000    15.000000
#
#        B_total_rounds_fought  B_total_title_bouts  B_win_by_Decision_Majority  \
# count            4896.000000          4896.000000                 4896.000000
# mean               10.742443             0.232639                    0.014502
# std                13.056366             1.022727                    0.121255
# min                 0.000000             0.000000                    0.000000
# 25%                 1.000000             0.000000                    0.000000
# 50%                 6.000000             0.000000                    0.000000
# 75%                15.000000             0.000000                    0.000000
# max                97.000000            16.000000                    2.000000
#
#        B_win_by_Decision_Split  B_win_by_Decision_Unanimous  B_win_by_KO/TKO  \
# count              4896.000000                  4896.000000      4896.000000
# mean                  0.260417                     0.975490         0.960989
# std                   0.577227                     1.495861         1.689694
# min                   0.000000                     0.000000         0.000000
# 25%                   0.000000                     0.000000         0.000000
# 50%                   0.000000                     0.000000         0.000000
# 75%                   0.000000                     1.000000         1.000000
# max                   5.000000                    10.000000        20.000000
#
#        B_win_by_Submission  B_win_by_TKO_Doctor_Stoppage       B_wins  \
# count          4896.000000                   4896.000000  4896.000000
# mean              0.588848                      0.029616     2.880923
# std               1.224983                      0.176625     3.608739
# min               0.000000                      0.000000     0.000000
# 25%               0.000000                      0.000000     0.000000
# 50%               0.000000                      0.000000     2.000000
# 75%               1.000000                      0.000000     4.000000
# max              13.000000                      2.000000    31.000000
#
#        B_Height_cms  B_Reach_cms  B_Weight_lbs  R_current_lose_streak  \
# count   4896.000000  4896.000000   4896.000000            4896.000000
# mean     178.084669   182.435958    164.803105               0.613154
# std        8.947115    10.995139     34.362908               0.861302
# min      152.400000     0.000000    115.000000               0.000000
# 25%      172.720000   175.260000    135.000000               0.000000
# 50%      177.800000   182.880000    155.000000               0.000000
# 75%      185.420000   190.500000    185.000000               1.000000
# max      210.820000   213.360000    265.000000               7.000000
#
#        R_current_win_streak       R_draw  R_avg_SIG_STR_landed  \
# count           4896.000000  4896.000000           4441.000000
# mean               1.051062     0.013480             27.396408
# std                1.698478     0.123872             19.871959
# min                0.000000     0.000000              0.000000
# 25%                0.000000     0.000000              8.280000
# 50%                0.000000     0.000000             26.000000
# 75%                1.000000     0.000000             40.090909
# max               16.000000     2.000000            141.000000
#
#        R_avg_SIG_STR_pct  R_avg_SUB_ATT  R_avg_TD_landed  R_avg_TD_pct  \
# count        4539.000000    4539.000000      4539.000000   4529.000000
# mean            0.454709       0.517659         1.337388      0.329411
# std             0.106335       0.651641         1.274270      0.228592
# min             0.000000       0.000000         0.000000      0.000000
# 25%             0.393333       0.000000         0.400000      0.172000
# 50%             0.451538       0.333333         1.000000      0.330000
# 75%             0.511000       0.800000         2.000000      0.466667
# max             1.000000       8.300000        12.500000      1.000000
#
#        R_longest_win_streak     R_losses  R_total_rounds_fought  \
# count           4896.000000  4896.000000            4896.000000
# mean               2.530842     2.393587              15.950980
# std                2.191512     2.488649              16.801419
# min                0.000000     0.000000               0.000000
# 25%                1.000000     1.000000               4.000000
# 50%                2.000000     2.000000              11.000000
# 75%                4.000000     3.000000              23.000000
# max               16.000000    18.000000             448.000000
#
#        R_total_title_bouts  R_win_by_Decision_Majority  \
# count          4896.000000                 4896.000000
# mean              0.552083                    0.025735
# std               1.499930                    0.160920
# min               0.000000                    0.000000
# 25%               0.000000                    0.000000
# 50%               0.000000                    0.000000
# 75%               0.000000                    0.000000
# max              16.000000                    2.000000
#
#        R_win_by_Decision_Split  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# count              4896.000000                  4896.000000      4896.000000
# mean                  0.365809                     1.468750         1.449551
# std                   0.666710                     1.821404         2.074385
# min                   0.000000                     0.000000         0.000000
# 25%                   0.000000                     0.000000         0.000000
# 50%                   0.000000                     1.000000         1.000000
# 75%                   1.000000                     2.000000         2.000000
# max                   5.000000                    10.000000        21.000000
#
#        R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage       R_wins  \
# count          4896.000000                   4896.000000  4896.000000
# mean              0.866422                      0.047386     4.293709
# std               1.495013                      0.229137     4.281123
# min               0.000000                      0.000000     0.000000
# 25%               0.000000                      0.000000     1.000000
# 50%               0.000000                      0.000000     3.000000
# 75%               1.000000                      0.000000     6.000000
# max              14.000000                      2.000000    33.000000
#
#        R_Height_cms  R_Reach_cms  R_Weight_lbs        R_age        B_age  \
# count   4896.000000  4896.000000   4896.000000  4896.000000  4896.000000
# mean     178.030948   182.619835    165.253472    30.056985    29.518382
# std        9.026469    10.879333     34.627769     4.115818     3.982299
# min      152.400000   152.400000    115.000000    19.000000    19.000000
# 25%      170.180000   175.260000    135.000000    27.000000    27.000000
# 50%      177.800000   182.880000    155.000000    30.000000    29.000000
# 75%      185.420000   190.500000    185.000000    33.000000    32.000000
# max      210.820000   214.630000    265.000000    47.000000    47.000000
#
#        lose_streak_dif  win_streak_dif  longest_win_streak_dif      win_dif  \
# count      4896.000000     4896.000000             4896.000000  4896.000000
# mean          0.105392       -0.175449               -0.765931    -1.412786
# std           0.994121        1.729648                2.029394     4.030496
# min          -5.000000      -13.000000              -12.000000   -28.000000
# 25%           0.000000       -1.000000               -2.000000    -3.000000
# 50%           0.000000        0.000000               -1.000000    -1.000000
# 75%           0.000000        0.000000                0.000000     0.000000
# max           6.000000        9.000000               14.000000    23.000000
#
#           loss_dif  total_round_dif  total_title_bout_dif       ko_dif  \
# count  4896.000000      4896.000000           4896.000000  4896.000000
# mean      0.370507        -5.208538             -0.319444    -0.506332
# std       2.873211        16.989572              1.649489     2.084517
# min     -18.000000      -448.000000            -16.000000   -21.000000
# 25%      -1.000000       -12.000000              0.000000    -1.000000
# 50%       0.000000        -3.000000              0.000000     0.000000
# 75%       2.000000         2.000000              0.000000     0.000000
# max      16.000000        80.000000             14.000000    14.000000
#
#            sub_dif   height_dif    reach_dif      age_dif  sig_str_dif  \
# count  4896.000000  4896.000000  4896.000000  4896.000000  4896.000000
# mean     -0.277574     0.018591    -0.251172     0.329044    -3.539160
# std       1.759247     6.963455     9.433336     5.174245    22.521709
# min     -13.000000  -187.960000  -187.960000   -17.000000  -118.000000
# 25%      -1.000000    -5.080000    -5.080000    -3.000000   -14.632937
# 50%       0.000000     0.000000     0.000000     0.000000    -0.750000
# 75%       0.000000     5.080000     5.080000     4.000000     4.741071
# max      10.000000    30.480000    30.480000    17.000000   128.222222
#
#        avg_sub_att_dif   avg_td_dif  empty_arena  constant_1  \
# count      4896.000000  4896.000000  4896.000000      4896.0
# mean         -0.061050    -0.201570     0.138480         1.0
# std           0.848169     1.701414     0.345439         0.0
# min          -8.300000   -11.000000     0.000000         1.0
# 25%          -0.419643    -1.000000     0.000000         1.0
# 50%           0.000000     0.000000     0.000000         1.0
# 75%           0.250000     0.600000     0.000000         1.0
# max           6.000000    10.860000     1.000000         1.0
#
#        B_match_weightclass_rank  R_match_weightclass_rank  \
# count                877.000000               1328.000000
# mean                   8.262258                  6.834337
# std                    4.198510                  4.613596
# min                    1.000000                  0.000000
# 25%                    5.000000                  3.000000
# 50%                    9.000000                  7.000000
# 75%                   12.000000                 11.000000
# max                   15.000000                 15.000000
#
#        R_Women's Flyweight_rank  R_Women's Featherweight_rank  \
# count                 59.000000                           7.0
# mean                   6.677966                           0.0
# std                    4.959980                           0.0
# min                    0.000000                           0.0
# 25%                    2.000000                           0.0
# 50%                    6.000000                           0.0
# 75%                   10.500000                           0.0
# max                   15.000000                           0.0
#
#        R_Women's Strawweight_rank  R_Women's Bantamweight_rank  \
# count                  104.000000                   118.000000
# mean                     6.826923                     7.050847
# std                      4.607807                     4.830189
# min                      0.000000                     0.000000
# 25%                      3.000000                     3.000000
# 50%                      6.500000                     7.000000
# 75%                     10.000000                    11.750000
# max                     15.000000                    15.000000
#
#        R_Heavyweight_rank  R_Light Heavyweight_rank  R_Middleweight_rank  \
# count          142.000000                141.000000           134.000000
# mean             6.774648                  6.673759             7.649254
# std              4.428141                  4.595800             4.637632
# min              0.000000                  0.000000             0.000000
# 25%              3.000000                  3.000000             4.000000
# 50%              6.500000                  6.000000             8.000000
# 75%             10.000000                 10.000000            12.000000
# max             15.000000                 15.000000            15.000000
#
#        R_Welterweight_rank  R_Lightweight_rank  R_Featherweight_rank  \
# count           140.000000          139.000000            133.000000
# mean              6.807143            7.093525              6.827068
# std               4.653298            4.576075              4.571836
# min               0.000000            0.000000              0.000000
# 25%               3.000000            3.000000              3.000000
# 50%               7.000000            6.000000              6.000000
# 75%              11.000000           11.000000             10.000000
# max              15.000000           15.000000             15.000000
#
#        R_Bantamweight_rank  R_Flyweight_rank  R_Pound-for-Pound_rank  \
# count           137.000000        142.000000              166.000000
# mean              6.985401          6.457746                6.789157
# std               4.617717          4.573472                4.147011
# min               0.000000          0.000000                1.000000
# 25%               3.000000          2.000000                3.000000
# 50%               7.000000          7.000000                6.000000
# 75%              11.000000         10.000000               10.000000
# max              15.000000         15.000000               15.000000
#
#        B_Women's Flyweight_rank  B_Women's Featherweight_rank  \
# count                 44.000000                           0.0
# mean                   7.795455                           NaN
# std                    3.950741                           NaN
# min                    1.000000                           NaN
# 25%                    5.000000                           NaN
# 50%                    7.000000                           NaN
# 75%                   10.250000                           NaN
# max                   15.000000                           NaN
#
#        B_Women's Strawweight_rank  B_Women's Bantamweight_rank  \
# count                   61.000000                    78.000000
# mean                     7.803279                     8.192308
# std                      4.269347                     4.378394
# min                      1.000000                     0.000000
# 25%                      4.000000                     5.000000
# 50%                      8.000000                     8.500000
# 75%                     11.000000                    11.750000
# max                     15.000000                    15.000000
#
#        B_Heavyweight_rank  B_Light Heavyweight_rank  B_Middleweight_rank  \
# count          110.000000                 93.000000           102.000000
# mean             8.490909                  8.268817             8.745098
# std              4.072160                  4.225028             4.209104
# min              1.000000                  0.000000             0.000000
# 25%              5.000000                  5.000000             5.000000
# 50%              9.000000                  9.000000             9.000000
# 75%             12.000000                 12.000000            12.000000
# max             15.000000                 15.000000            15.000000
#
#        B_Welterweight_rank  B_Lightweight_rank  B_Featherweight_rank  \
# count            89.000000           87.000000             90.000000
# mean              8.179775            8.126437              8.022222
# std               4.373374            4.119733              4.303063
# min               1.000000            1.000000              0.000000
# 25%               4.000000            5.000000              4.250000
# 50%               8.000000            8.000000              8.500000
# 75%              12.000000           11.500000             11.750000
# max              15.000000           15.000000             15.000000
#
#        B_Bantamweight_rank  B_Flyweight_rank  B_Pound-for-Pound_rank  \
# count            85.000000         95.000000               35.000000
# mean              8.388235          8.473684                9.485714
# std               4.397223          4.259763                4.300283
# min               0.000000          1.000000                2.000000
# 25%               4.000000          5.000000                5.000000
# 50%               9.000000          8.000000               10.000000
# 75%              12.000000         12.000000               13.500000
# max              15.000000         15.000000               15.000000
#
#        finish_round  total_fight_time_secs   r_dec_odds   b_dec_odds  \
# count   4274.000000            4274.000000  4093.000000  4077.000000
# mean       2.408049             652.313758   294.064745   416.544027
# std        0.996643             357.911423   230.583958   306.571299
# min        1.000000               5.000000  -440.000000  -200.000000
# 25%        1.000000             297.000000   167.000000   225.000000
# 50%        3.000000             900.000000   250.000000   349.000000
# 75%        3.000000             900.000000   400.000000   525.000000
# max        5.000000            1500.000000  2200.000000  2600.000000
#
#         r_sub_odds   b_sub_odds    r_ko_odds    b_ko_odds
# count  3847.000000  3835.000000  3847.000000  3834.000000
# mean    843.010138  1064.543155   514.231869   647.257173
# std     550.126761   627.285034   413.622768   458.846643
# min    -370.000000 -1250.000000  -550.000000  -275.000000
# 25%     435.000000   590.000000   240.000000   325.000000
# 50%     720.000000   975.000000   435.000000   548.500000
# 75%    1200.000000  1400.000000   700.000000   880.750000
# max    4665.000000  4785.000000  2675.000000  3200.000000

# %%
# turn into datetime and sort

df[['date']] = df[['date']].apply(pd.to_datetime)

df.sort_values(by=['date'], inplace=True)

# %%
df.sort_values(by=['date'], inplace=True)

# %%
df.nunique()
# Out:
# R_fighter                       1348
# B_fighter                       1591
# R_odds                           328
# B_odds                           340
# R_ev                             330
# B_ev                             345
# date                             428
# location                         145
# country                           28
# Winner                             2
# title_bout                         2
# weight_class                      13
# gender                             2
# no_of_rounds                       3
# B_current_lose_streak              7
# B_current_win_streak              12
# B_draw                             3
# B_avg_SIG_STR_landed            1566
# B_avg_SIG_STR_pct                977
# B_avg_SUB_ATT                    245
# B_avg_TD_landed                  611
# B_avg_TD_pct                     939
# B_longest_win_streak              16
# B_losses                          16
# B_total_rounds_fought             83
# B_total_title_bouts               16
# B_win_by_Decision_Majority         3
# B_win_by_Decision_Split            6
# B_win_by_Decision_Unanimous       11
# B_win_by_KO/TKO                   14
# B_win_by_Submission               13
# B_win_by_TKO_Doctor_Stoppage       3
# B_wins                            26
# B_Stance                           5
# B_Height_cms                      23
# B_Reach_cms                       59
# B_Weight_lbs                      36
# R_current_lose_streak              8
# R_current_win_streak              17
# R_draw                             3
# R_avg_SIG_STR_landed            1901
# R_avg_SIG_STR_pct               1267
# R_avg_SUB_ATT                    277
# R_avg_TD_landed                  713
# R_avg_TD_pct                    1260
# R_longest_win_streak              17
# R_losses                          19
# R_total_rounds_fought             90
# R_total_title_bouts               16
# R_win_by_Decision_Majority         3
# R_win_by_Decision_Split            6
# R_win_by_Decision_Unanimous       11
# R_win_by_KO/TKO                   16
# R_win_by_Submission               15
# R_win_by_TKO_Doctor_Stoppage       3
# R_wins                            28
# R_Stance                           4
# R_Height_cms                      22
# R_Reach_cms                       50
# R_Weight_lbs                      33
# R_age                             28
# B_age                             29
# lose_streak_dif                   12
# win_streak_dif                    23
# longest_win_streak_dif            24
# win_dif                           43
# loss_dif                          34
# total_round_dif                  142
# total_title_bout_dif              29
# ko_dif                            27
# sub_dif                           24
# height_dif                        26
# reach_dif                        122
# age_dif                           35
# sig_str_dif                     2806
# avg_sub_att_dif                  898
# avg_td_dif                      1607
# empty_arena                        2
# constant_1                         1
# B_match_weightclass_rank          15
# R_match_weightclass_rank          16
# R_Women's Flyweight_rank          16
# R_Women's Featherweight_rank       1
# R_Women's Strawweight_rank        16
# R_Women's Bantamweight_rank       16
# R_Heavyweight_rank                16
# R_Light Heavyweight_rank          16
# R_Middleweight_rank               16
# R_Welterweight_rank               16
# R_Lightweight_rank                16
# R_Featherweight_rank              16
# R_Bantamweight_rank               16
# R_Flyweight_rank                  16
# R_Pound-for-Pound_rank            15
# B_Women's Flyweight_rank          15
# B_Women's Featherweight_rank       0
# B_Women's Strawweight_rank        15
# B_Women's Bantamweight_rank       16
# B_Heavyweight_rank                15
# B_Light Heavyweight_rank          16
# B_Middleweight_rank               16
# B_Welterweight_rank               15
# B_Lightweight_rank                15
# B_Featherweight_rank              16
# B_Bantamweight_rank               16
# B_Flyweight_rank                  15
# B_Pound-for-Pound_rank            14
# better_rank                        3
# finish                             7
# finish_details                    31
# finish_round                       5
# finish_round_time                293
# total_fight_time_secs            788
# r_dec_odds                       572
# b_dec_odds                       626
# r_sub_odds                       687
# b_sub_odds                       664
# r_ko_odds                        607
# b_ko_odds                        581
# dtype: int64

# %%
# null counts

df.isnull().sum()
# Out:
# R_fighter                          0
# B_fighter                          0
# R_odds                             1
# B_odds                             0
# R_ev                               1
# B_ev                               0
# date                               0
# location                           0
# country                            0
# Winner                             0
# title_bout                         0
# weight_class                       0
# gender                             0
# no_of_rounds                       0
# B_current_lose_streak              0
# B_current_win_streak               0
# B_draw                             0
# B_avg_SIG_STR_landed             930
# B_avg_SIG_STR_pct                765
# B_avg_SUB_ATT                    832
# B_avg_TD_landed                  833
# B_avg_TD_pct                     842
# B_longest_win_streak               0
# B_losses                           0
# B_total_rounds_fought              0
# B_total_title_bouts                0
# B_win_by_Decision_Majority         0
# B_win_by_Decision_Split            0
# B_win_by_Decision_Unanimous        0
# B_win_by_KO/TKO                    0
# B_win_by_Submission                0
# B_win_by_TKO_Doctor_Stoppage       0
# B_wins                             0
# B_Stance                           2
# B_Height_cms                       0
# B_Reach_cms                        0
# B_Weight_lbs                       0
# R_current_lose_streak              0
# R_current_win_streak               0
# R_draw                             0
# R_avg_SIG_STR_landed             455
# R_avg_SIG_STR_pct                357
# R_avg_SUB_ATT                    357
# R_avg_TD_landed                  357
# R_avg_TD_pct                     367
# R_longest_win_streak               0
# R_losses                           0
# R_total_rounds_fought              0
# R_total_title_bouts                0
# R_win_by_Decision_Majority         0
# R_win_by_Decision_Split            0
# R_win_by_Decision_Unanimous        0
# R_win_by_KO/TKO                    0
# R_win_by_Submission                0
# R_win_by_TKO_Doctor_Stoppage       0
# R_wins                             0
# R_Stance                           0
# R_Height_cms                       0
# R_Reach_cms                        0
# R_Weight_lbs                       0
# R_age                              0
# B_age                              0
# lose_streak_dif                    0
# win_streak_dif                     0
# longest_win_streak_dif             0
# win_dif                            0
# loss_dif                           0
# total_round_dif                    0
# total_title_bout_dif               0
# ko_dif                             0
# sub_dif                            0
# height_dif                         0
# reach_dif                          0
# age_dif                            0
# sig_str_dif                        0
# avg_sub_att_dif                    0
# avg_td_dif                         0
# empty_arena                        0
# constant_1                         0
# B_match_weightclass_rank        4019
# R_match_weightclass_rank        3568
# R_Women's Flyweight_rank        4837
# R_Women's Featherweight_rank    4889
# R_Women's Strawweight_rank      4792
# R_Women's Bantamweight_rank     4778
# R_Heavyweight_rank              4754
# R_Light Heavyweight_rank        4755
# R_Middleweight_rank             4762
# R_Welterweight_rank             4756
# R_Lightweight_rank              4757
# R_Featherweight_rank            4763
# R_Bantamweight_rank             4759
# R_Flyweight_rank                4754
# R_Pound-for-Pound_rank          4730
# B_Women's Flyweight_rank        4852
# B_Women's Featherweight_rank    4896
# B_Women's Strawweight_rank      4835
# B_Women's Bantamweight_rank     4818
# B_Heavyweight_rank              4786
# B_Light Heavyweight_rank        4803
# B_Middleweight_rank             4794
# B_Welterweight_rank             4807
# B_Lightweight_rank              4809
# B_Featherweight_rank            4806
# B_Bantamweight_rank             4811
# B_Flyweight_rank                4801
# B_Pound-for-Pound_rank          4861
# better_rank                        0
# finish                           238
# finish_details                  2794
# finish_round                     622
# finish_round_time                622
# total_fight_time_secs            622
# r_dec_odds                       803
# b_dec_odds                       819
# r_sub_odds                      1049
# b_sub_odds                      1061
# r_ko_odds                       1049
# b_ko_odds                       1062
# dtype: int64

# %% [markdown]
# ### Getting rid of bad data

# %%
# doctor stoppage is when a fight is dropped due to an unforseen medical issue .ie a broken leg. 
# Usually this cannot be predicted and ruins the data so I am getting rid of it

df = df[ df.B_win_by_TKO_Doctor_Stoppage == 0]
df = df[ df.R_win_by_TKO_Doctor_Stoppage == 0]

# %%
# we see the counts for the types of finishes

df[['finish','r_ko_odds']].groupby('finish').count()
# Out:
#             r_ko_odds
# finish
# DQ                  8
# KO/TKO           1115
# M-DEC              25
# Overturned          2
# S-DEC             363
# SUB               601
# U-DEC            1314

# %%
# dropping the disqualified and overturned rounds because that is not fair and ruins the data

df = df[df.finish != 'Overturned']

df = df[df.finish != 'DQ']

# %% [markdown]
# ### Feature engineering

# %%
from cmath import nan

# create funnction that encodes better rank as a variable
# not sure if I should ohe or ordinally encode this, but I one-hot-encoded the data set Winner red becomes 1 and blue is 0 so it makes sense that better_rank red is 2
def encoder(x):
    if x == 'Blue':
        return 1
    elif x == 'Red':
        return 2
    elif x == 'neither':
        return 0
    else:
        return nan
    
# create new column
df['encoded_better_rank']=[encoder(x) for x in df['better_rank']]

# %%
# check for nulls

df[['encoded_better_rank']].isnull().sum()
# Out:
# encoded_better_rank    0
# dtype: int64

# %%
# Feature Engineering create difference

# weight
df['weight_diff']=df['R_Weight_lbs'] - df['B_Weight_lbs']

# for betting odds most of the time it's combined
df['win_by_decision_diff'] = df['R_win_by_Decision_Majority'] + df['R_win_by_Decision_Split'] + df['R_win_by_Decision_Unanimous'] - df['B_win_by_Decision_Majority'] - df['B_win_by_Decision_Split'] - df['B_win_by_Decision_Unanimous']

# %%
# null counts

df.isnull().sum()
# Out:
# R_fighter                 0
# B_fighter                 0
# R_odds                    1
# B_odds                    0
# R_ev                      1
#                        ...
# r_ko_odds               950
# b_ko_odds               963
# encoded_better_rank       0
# weight_diff               0
# win_by_decision_diff      0
# Length: 122, dtype: int64

# %%
# create wins losses percent feature

#Blue

df['B_fights_fought'] = df['B_losses']+df['B_wins']+df['B_draw']

df['B_win_percent']=(round(df['B_wins']/df['B_fights_fought'])).fillna(0)

df['B_loss_percent']=round(df['B_losses']/df['B_fights_fought']).fillna(0)

# Red

df['R_fights_fought'] = (df['R_losses']+df['R_wins']+df['R_draw'])

df['R_win_percent']=round(df['R_wins']/df['R_fights_fought']).fillna(0)

df['R_loss_percent']=round(df['R_losses']/df['R_fights_fought']).fillna(0)

# diff

df['diff_wins+percent'] = df['R_win_percent'] - df['B_win_percent']

df['diff_loss_percent'] =df['R_loss_percent'] - df['B_loss_percent']

df['diff_fights_fought'] =df['R_fights_fought'] - df['B_fights_fought']

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'date',
#        'location', 'country', 'Winner',
#        ...
#        'win_by_decision_diff', 'B_fights_fought', 'B_win_percent',
#        'B_loss_percent', 'R_fights_fought', 'R_win_percent', 'R_loss_percent',
#        'diff_wins+percent', 'diff_loss_percent', 'diff_fights_fought'],
#       dtype='object', length=131)

# %% [markdown]
# #### Date time and Time deltas

# %%
df['date'] =pd.to_datetime(df['date'])


#turn datetime into object that the models can use
df['days from current date']=datetime.now()-df['date']

df['days from current date']=df['days from current date'].apply(lambda x: x.days)


#drop date
df = df.drop(['date'], axis=1, errors='ignore')

# %% [markdown]
# ### Dropping unnecessary columns

# %%
# type of submission 'B_win_by_Decision_Unanimous','B_win_by_Decision_Split','B_win_by_Decision_Majority','B_win_by_Submission','B_win_by_KO/TKO',

# %%
# df

# dropping these because there are already feature engineered differences

# b_fighters
to_drop_b=['B_Pound-for-Pound_rank','B_win_by_TKO_Doctor_Stoppage','B_age','B_Weight_lbs','B_losses','B_wins','B_total_title_bouts','B_total_rounds_fought','B_longest_win_streak',
           'B_draw','B_avg_SIG_STR_pct','B_avg_SIG_STR_landed','B_avg_SUB_ATT','B_avg_TD_pct',
           'B_avg_TD_landed','B_Height_cms','B_Reach_cms','B_current_lose_streak','B_current_win_streak',
           "B_Women's Flyweight_rank", "B_Women's Featherweight_rank", "B_Women's Strawweight_rank", "B_Women's Bantamweight_rank", 
           'B_Heavyweight_rank', 'B_Light Heavyweight_rank', 'B_Middleweight_rank', 'B_Welterweight_rank', 'B_Lightweight_rank', 
           'B_Featherweight_rank', 'B_Bantamweight_rank', 'B_Flyweight_rank']

# unrelated to fighters
to_drop=['constant_1','location','country','no_of_rounds','empty_arena','finish_details','finish_round_time','total_fight_time_secs']

#dropping R fighters
to_drop_r= [re.sub(r'^.', 'R', s).strip() for s in to_drop_b]

df2=copy.deepcopy(df)

# drop
df.drop(to_drop_b, axis=1, inplace=True)

df.drop(to_drop_r, axis=1, inplace=True)

df.drop(to_drop, axis=1, inplace=True)

# %%
df.describe()
# Out:
#             R_odds       B_odds         R_ev         B_ev  \
# count  4538.000000  4539.000000  4538.000000  4539.000000
# mean   -117.605553    65.640229    94.601874   166.547600
# std     267.862385   246.955440    82.452264   136.364516
# min   -1700.000000 -1200.000000     5.882353     8.333333
# 25%    -250.000000  -145.000000    40.000000    68.965517
# 50%    -150.000000   130.000000    66.666667   130.000000
# 75%     125.000000   220.000000   125.000000   220.000000
# max     775.000000  1300.000000   775.000000  1300.000000
#
#        B_win_by_Decision_Majority  B_win_by_Decision_Split  \
# count                 4539.000000              4539.000000
# mean                     0.013659                 0.241243
# std                      0.117968                 0.549217
# min                      0.000000                 0.000000
# 25%                      0.000000                 0.000000
# 50%                      0.000000                 0.000000
# 75%                      0.000000                 0.000000
# max                      2.000000                 5.000000
#
#        B_win_by_Decision_Unanimous  B_win_by_KO/TKO  B_win_by_Submission  \
# count                  4539.000000      4539.000000          4539.000000
# mean                      0.923331         0.879269             0.563120
# std                       1.464981         1.614708             1.205492
# min                       0.000000         0.000000             0.000000
# 25%                       0.000000         0.000000             0.000000
# 50%                       0.000000         0.000000             0.000000
# 75%                       1.000000         1.000000             1.000000
# max                      10.000000        20.000000            13.000000
#
#        R_win_by_Decision_Majority  R_win_by_Decision_Split  \
# count                 4539.000000              4539.000000
# mean                     0.024675                 0.354043
# std                      0.157965                 0.654182
# min                      0.000000                 0.000000
# 25%                      0.000000                 0.000000
# 50%                      0.000000                 0.000000
# 75%                      0.000000                 1.000000
# max                      2.000000                 4.000000
#
#        R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# count                  4539.000000      4539.000000          4539.000000
# mean                      1.408240         1.348094             0.833223
# std                       1.791743         2.006930             1.466893
# min                       0.000000         0.000000             0.000000
# 25%                       0.000000         0.000000             0.000000
# 50%                       1.000000         1.000000             0.000000
# 75%                       2.000000         2.000000             1.000000
# max                      10.000000        21.000000            14.000000
#
#        lose_streak_dif  win_streak_dif  longest_win_streak_dif      win_dif  \
# count      4539.000000     4539.000000             4539.000000  4539.000000
# mean          0.097158       -0.184622               -0.752368    -1.368804
# std           0.979309        1.682571                1.995680     3.904903
# min          -5.000000      -13.000000              -12.000000   -28.000000
# 25%           0.000000       -1.000000               -2.000000    -3.000000
# 50%           0.000000        0.000000               -1.000000    -1.000000
# 75%           0.000000        0.000000                0.000000     0.000000
# max           5.000000        9.000000               14.000000    23.000000
#
#           loss_dif  total_round_dif  total_title_bout_dif       ko_dif  \
# count  4539.000000      4539.000000           4539.000000  4539.000000
# mean      0.337960        -5.088125             -0.274289    -0.468826
# std       2.744744        16.439217              1.492120     1.944035
# min     -18.000000      -448.000000            -14.000000   -21.000000
# 25%      -1.000000       -11.000000              0.000000    -1.000000
# 50%       0.000000        -3.000000              0.000000     0.000000
# 75%       2.000000         2.000000              0.000000     0.000000
# max      16.000000        80.000000             14.000000    14.000000
#
#            sub_dif   height_dif    reach_dif      age_dif  sig_str_dif  \
# count  4539.000000  4539.000000  4539.000000  4539.000000  4539.000000
# mean     -0.270104     0.021172    -0.262412     0.298965    -3.694229
# std       1.730323     7.040320     9.505267     5.185567    22.606399
# min     -13.000000  -187.960000  -187.960000   -17.000000  -118.000000
# 25%      -1.000000    -5.080000    -5.080000    -3.000000   -14.636243
# 50%       0.000000     0.000000     0.000000     0.000000    -0.750000
# 75%       0.000000     5.080000     5.080000     4.000000     4.012987
# max      10.000000    30.480000    30.480000    17.000000   128.222222
#
#        avg_sub_att_dif   avg_td_dif  B_match_weightclass_rank  \
# count      4539.000000  4539.000000                790.000000
# mean         -0.063034    -0.210209                  8.336709
# std           0.867129     1.721720                  4.240315
# min          -8.300000   -11.000000                  1.000000
# 25%          -0.440000    -1.000000                  5.000000
# 50%           0.000000     0.000000                  9.000000
# 75%           0.237424     0.600000                 12.000000
# max           6.000000    10.860000                 15.000000
#
#        R_match_weightclass_rank  finish_round   r_dec_odds   b_dec_odds  \
# count               1202.000000   3927.000000  3821.000000  3808.000000
# mean                   6.922629      2.414057   294.095001   414.601103
# std                    4.646523      0.991398   230.361088   304.652550
# min                    0.000000      1.000000  -440.000000  -200.000000
# 25%                    3.000000      1.000000   167.000000   225.000000
# 50%                    7.000000      3.000000   250.000000   347.500000
# 75%                   11.000000      3.000000   395.000000   525.000000
# max                   15.000000      5.000000  2200.000000  2600.000000
#
#         r_sub_odds   b_sub_odds    r_ko_odds    b_ko_odds  \
# count  3589.000000  3577.000000  3589.000000  3576.000000
# mean    836.545277  1055.214425   517.899136   652.522092
# std     548.162720   626.734296   413.558169   460.338676
# min    -370.000000 -1250.000000  -550.000000  -275.000000
# 25%     430.000000   585.000000   242.000000   325.000000
# 50%     701.000000   950.000000   439.000000   550.000000
# 75%    1190.000000  1400.000000   700.000000   900.000000
# max    4665.000000  4785.000000  2675.000000  3200.000000
#
#        encoded_better_rank  weight_diff  win_by_decision_diff  \
# count          4539.000000  4539.000000           4539.000000
# mean              0.532716     0.437762              0.608724
# std               0.875439     9.501910              2.214435
# min               0.000000   -75.000000            -10.000000
# 25%               0.000000     0.000000              0.000000
# 50%               0.000000     0.000000              0.000000
# 75%               2.000000     0.000000              1.000000
# max               2.000000    80.000000             12.000000
#
#        B_fights_fought  B_win_percent  B_loss_percent  R_fights_fought  \
# count      4539.000000    4539.000000     4539.000000      4539.000000
# mean          4.298083       0.459132        0.208196         6.324741
# std           5.095900       0.498382        0.406062         6.149585
# min           0.000000       0.000000        0.000000         0.000000
# 25%           1.000000       0.000000        0.000000         2.000000
# 50%           3.000000       0.000000        0.000000         4.000000
# 75%           6.000000       1.000000        0.000000         9.000000
# max          43.000000       1.000000        1.000000        48.000000
#
#        R_win_percent  R_loss_percent  diff_wins+percent  diff_loss_percent  \
# count    4539.000000     4539.000000        4539.000000        4539.000000
# mean        0.604538        0.171403           0.145406          -0.036792
# std         0.489003        0.376903           0.545431           0.494317
# min         0.000000        0.000000          -1.000000          -1.000000
# 25%         0.000000        0.000000           0.000000           0.000000
# 50%         1.000000        0.000000           0.000000           0.000000
# 75%         1.000000        0.000000           0.000000           0.000000
# max         1.000000        1.000000           1.000000           1.000000
#
#        diff_fights_fought  days from current date
# count         4539.000000             4539.000000
# mean             2.026658             2281.445252
# std              6.162372             1158.844533
# min            -27.000000              402.000000
# 25%             -1.000000             1277.000000
# 50%              1.000000             2236.000000
# 75%              5.000000             3181.000000
# max             43.000000             4615.000000

# %%
df.isnull().sum()

# Null - value turns it into a zero might have to drop those first so i might need to drop the nullvalues before hand??
# not sure how i should handle it as i may not need to drop them later on depending on the algorithm that i use
# Out:
# R_fighter                         0
# B_fighter                         0
# R_odds                            1
# B_odds                            0
# R_ev                              1
# B_ev                              0
# Winner                            0
# title_bout                        0
# weight_class                      0
# gender                            0
# B_win_by_Decision_Majority        0
# B_win_by_Decision_Split           0
# B_win_by_Decision_Unanimous       0
# B_win_by_KO/TKO                   0
# B_win_by_Submission               0
# B_Stance                          2
# R_win_by_Decision_Majority        0
# R_win_by_Decision_Split           0
# R_win_by_Decision_Unanimous       0
# R_win_by_KO/TKO                   0
# R_win_by_Submission               0
# R_Stance                          0
# lose_streak_dif                   0
# win_streak_dif                    0
# longest_win_streak_dif            0
# win_dif                           0
# loss_dif                          0
# total_round_dif                   0
# total_title_bout_dif              0
# ko_dif                            0
# sub_dif                           0
# height_dif                        0
# reach_dif                         0
# age_dif                           0
# sig_str_dif                       0
# avg_sub_att_dif                   0
# avg_td_dif                        0
# B_match_weightclass_rank       3749
# R_match_weightclass_rank       3337
# better_rank                       0
# finish                          230
# finish_round                    612
# r_dec_odds                      718
# b_dec_odds                      731
# r_sub_odds                      950
# b_sub_odds                      962
# r_ko_odds                       950
# b_ko_odds                       963
# encoded_better_rank               0
# weight_diff                       0
# win_by_decision_diff              0
# B_fights_fought                   0
# B_win_percent                     0
# B_loss_percent                    0
# R_fights_fought                   0
# R_win_percent                     0
# R_loss_percent                    0
# diff_wins+percent                 0
# diff_loss_percent                 0
# diff_fights_fought                0
# days from current date            0
# dtype: int64

# %%
df # how our dataset looks like
# Out:
#                 R_fighter        B_fighter  R_odds  B_odds        R_ev  \
# 4895         Eric Schafer      Jason Brilz   140.0    -160  140.000000
# 4885         Brandon Vera        Jon Jones   215.0    -235  215.000000
# 4886    Junior Dos Santos  Gabriel Gonzaga  -250.0     230   40.000000
# 4888       Alessio Sakara      James Irvin  -120.0     100   83.333333
# 4894          Mike Pierce    Julio Paulino  -420.0     335   23.809524
# ...                   ...              ...     ...     ...         ...
# 2          Misha Cirkunov  Krzysztof Jotko   110.0    -130  110.000000
# 1           Alex Oliveira       Niko Price   170.0    -200  170.000000
# 5     Antonina Shevchenko    Casey O'Neill   215.0    -265  215.000000
# 7           Devonte Smith  Jamie Mullarkey  -155.0     135   64.516129
# 0           Thiago Santos    Johnny Walker  -150.0     130   66.666667
#
#             B_ev Winner  title_bout       weight_class  gender  \
# 4895   62.500000   Blue       False  Light Heavyweight    MALE
# 4885   42.553191   Blue       False  Light Heavyweight    MALE
# 4886  230.000000    Red       False        Heavyweight    MALE
# 4888  100.000000    Red       False       Middleweight    MALE
# 4894  335.000000    Red       False       Welterweight    MALE
# ...          ...    ...         ...                ...     ...
# 2      76.923077   Blue       False       Middleweight    MALE
# 1      50.000000   Blue       False       Welterweight    MALE
# 5      37.735849   Blue       False  Women's Flyweight  FEMALE
# 7     135.000000   Blue       False        Lightweight    MALE
# 0     130.000000    Red       False  Light Heavyweight    MALE
#
#       B_win_by_Decision_Majority  B_win_by_Decision_Split  \
# 4895                           0                        0
# 4885                           0                        0
# 4886                           0                        0
# 4888                           0                        0
# 4894                           0                        0
# ...                          ...                      ...
# 2                              0                        2
# 1                              0                        0
# 5                              0                        0
# 7                              0                        0
# 0                              0                        0
#
#       B_win_by_Decision_Unanimous  B_win_by_KO/TKO  B_win_by_Submission  \
# 4895                            1                1                    0
# 4885                            2                0                    1
# 4886                            0                5                    2
# 4888                            0                3                    0
# 4894                            0                0                    0
# ...                           ...              ...                  ...
# 2                               6                1                    0
# 1                               0                4                    2
# 5                               0                1                    1
# 7                               0                1                    0
# 0                               1                4                    0
#
#       B_Stance  R_win_by_Decision_Majority  R_win_by_Decision_Split  \
# 4895  Orthodox                           0                        0
# 4885  Orthodox                           0                        0
# 4886  Orthodox                           0                        0
# 4888  Orthodox                           0                        1
# 4894  Orthodox                           0                        0
# ...        ...                         ...                      ...
# 2     Southpaw                           0                        0
# 1     Orthodox                           0                        1
# 5     Orthodox                           0                        0
# 7     Orthodox                           0                        0
# 0     Orthodox                           0                        0
#
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 4895                            0                1                    2
# 4885                            2                4                    1
# 4886                            0                4                    0
# 4888                            1                3                    0
# 4894                            1                0                    0
# ...                           ...              ...                  ...
# 2                               0                1                    5
# 1                               3                4                    3
# 5                               1                2                    1
# 7                               0                4                    0
# 0                               2               11                    0
#
#       R_Stance  lose_streak_dif  win_streak_dif  longest_win_streak_dif  \
# 4895  Orthodox                0               0                       0
# 4885  Orthodox                0               0                      -1
# 4886  Orthodox                0              -3                       0
# 4888  Orthodox               -1              -2                       0
# 4894  Orthodox                1               0                      -1
# ...        ...              ...             ...                     ...
# 2     Orthodox                0               0                       1
# 1     Orthodox                0               0                      -2
# 5     Southpaw               -1               2                       0
# 7     Orthodox                0               0                      -2
# 0     Orthodox               -3               1                       0
#
#       win_dif  loss_dif  total_round_dif  total_title_bout_dif  ko_dif  \
# 4895       -1         2               -1                     0       0
# 4885       -4         3              -14                     0      -4
# 4886        3        -3               10                     1       1
# 4888       -1         1               -5                     0       0
# 4894       -1         1               -6                     0       0
# ...       ...       ...              ...                   ...     ...
# 2           3         1               25                     0       0
# 1          -5        -3              -20                     0       0
# 5          -2        -3              -12                     0      -1
# 7          -3         1                1                     0      -3
# 0          -8        -6              -32                    -1      -7
#
#       sub_dif  height_dif  reach_dif  age_dif  sig_str_dif  avg_sub_att_dif  \
# 4895       -2      -10.16     -10.16       -2    16.000000        -0.666667
# 4885        0        2.54      20.32       10     8.272727         0.159091
# 4886        2       -5.08      -2.54       -4   -12.050000         0.700000
# 4888        0        5.08       7.62       -3   -15.550000         0.125000
# 4894        0       10.16       7.62       -5   -40.500000         0.000000
# ...       ...         ...        ...      ...          ...              ...
# 2          -5       -5.08       0.00       -2    -0.850000        -1.600000
# 1          -1        2.54       0.00       -1     2.190000         0.300000
# 5           0       -5.08       5.08      -13     1.590000         0.900000
# 7           0        7.62      -5.08       -1    -2.070000        -0.100000
# 0           0       10.16      15.24       -8    -0.530000         0.600000
#
#       avg_td_dif  B_match_weightclass_rank  R_match_weightclass_rank  \
# 4895    0.833333                       NaN                       NaN
# 4885    1.954545                       NaN                       NaN
# 4886    1.200000                       NaN                       NaN
# 4888   -1.000000                       NaN                       NaN
# 4894   -3.500000                       NaN                       NaN
# ...          ...                       ...                       ...
# 2      -3.330000                       NaN                       NaN
# 1      -1.480000                       NaN                       NaN
# 5       3.320000                       NaN                       NaN
# 7       2.970000                       NaN                       NaN
# 0      -0.370000                      10.0                       5.0
#
#      better_rank  finish  finish_round  r_dec_odds  b_dec_odds  r_sub_odds  \
# 4895     neither   U-DEC           3.0         NaN         NaN         NaN
# 4885     neither  KO/TKO           1.0         NaN         NaN         NaN
# 4886     neither  KO/TKO           1.0         NaN         NaN         NaN
# 4888     neither  KO/TKO           1.0         NaN         NaN         NaN
# 4894     neither   U-DEC           3.0         NaN         NaN         NaN
# ...          ...     ...           ...         ...         ...         ...
# 2        neither   S-DEC           3.0       550.0       275.0       275.0
# 1        neither   U-DEC           3.0       450.0       350.0       700.0
# 5        neither  KO/TKO           2.0       300.0       200.0      1600.0
# 7        neither  KO/TKO           2.0       330.0       450.0      2000.0
# 0            Red   U-DEC           5.0       800.0       900.0      2000.0
#
#       b_sub_odds  r_ko_odds  b_ko_odds  encoded_better_rank  weight_diff  \
# 4895         NaN        NaN        NaN                    0          -20
# 4885         NaN        NaN        NaN                    0           25
# 4886         NaN        NaN        NaN                    0           -4
# 4888         NaN        NaN        NaN                    0          -20
# 4894         NaN        NaN        NaN                    0            0
# ...          ...        ...        ...                  ...          ...
# 2         1400.0      600.0      185.0                    0           20
# 1         1100.0      550.0      120.0                    0            0
# 5          330.0     1000.0      300.0                    0            0
# 7          900.0      140.0      330.0                    0            0
# 0         1600.0     -110.0      175.0                    2            0
#
#       win_by_decision_diff  B_fights_fought  B_win_percent  B_loss_percent  \
# 4895                    -1                3            1.0             0.0
# 4885                     0                4            1.0             0.0
# 4886                     0               10            1.0             0.0
# 4888                     2                8            0.0             0.0
# 4894                     1                0            0.0             0.0
# ...                    ...              ...            ...             ...
# 2                       -8               14            1.0             0.0
# 1                        4               11            1.0             0.0
# 5                        1                2            1.0             0.0
# 7                        0                3            0.0             1.0
# 0                        1                7            1.0             0.0
#
#       R_fights_fought  R_win_percent  R_loss_percent  diff_wins+percent  \
# 4895                6            0.0             0.0               -1.0
# 4885               11            1.0             0.0                0.0
# 4886                4            1.0             0.0                0.0
# 4888               10            0.0             0.0                0.0
# 4894                2            0.0             0.0                0.0
# ...               ...            ...             ...                ...
# 2                  10            1.0             0.0                0.0
# 1                  19            1.0             0.0                0.0
# 5                   7            1.0             0.0                0.0
# 7                   5            1.0             0.0                1.0
# 0                  21            1.0             0.0                0.0
#
#       diff_loss_percent  diff_fights_fought  days from current date
# 4895                0.0                   3                    4615
# 4885                0.0                   7                    4615
# 4886                0.0                  -6                    4615
# 4888                0.0                   2                    4615
# 4894                0.0                   2                    4615
# ...                 ...                 ...                     ...
# 2                   0.0                  -4                     402
# 1                   0.0                   8                     402
# 5                   0.0                   5                     402
# 7                  -1.0                   2                     402
# 0                   0.0                  14                     402
#
# [4539 rows x 61 columns]

# %% [markdown]
# # Export

# %%
df.to_csv('pre-processed_new.csv', index=False)

# %%
df2.to_csv('pre-processed2.csv', index=False)
